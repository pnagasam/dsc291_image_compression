# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import mean_squared_error
import os

# %%
fp = "DIV2K_valid_HR/0801.png"
im = cv2.imread(fp, cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))

# %%
cv2.imwrite('test.jpg', im, [int(cv2.IMWRITE_JPEG_QUALITY), 50])
# Out:
# True

# %%
im_jpeg = cv2.imread('test.jpg')

# %%
mean_squared_error(im, im_jpeg)
# Out:
# 29.221807338963117

# %%
ssim(im, im_jpeg, data_range=im.max() - im.min(), multichannel=True)
# Out:
# 0.9431881354222802

# %%
os.path.getsize("test.jpg")
# Out:
# 320848

# %%
import tensorflow as tf
import tensorflow_compression as tfc
# Out:
# 2022-06-05 13:32:34.377298: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-06-05 13:32:34.383102: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:32:34.383119: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# !python tfci.py -h
# Out:
# 2022-06-05 13:33:12.324587: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-06-05 13:33:12.330139: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:33:12.330170: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/pnagasam/.local/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:561: calling function (from tensorflow.python.eager.def_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# usage: tfci.py [-h] [--helpfull] [--url_prefix URL_PREFIX]
#                [--metagraph_cache METAGRAPH_CACHE]
#                {compress,decompress,models,tensors,dump} ...
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --helpfull            show full help message and exit
#   --url_prefix URL_PREFIX
#                         URL prefix for downloading model metagraphs. (default:
#                         https://storage.googleapis.com/tensorflow_compression/
#                         metagraphs)
#   --metagraph_cache METAGRAPH_CACHE
#                         Directory where to cache model metagraphs. (default:
#                         /tmp/tfc_metagraphs)
#
# commands:
#   {compress,decompress,models,tensors,dump}
#                         Invoke '<command> -h' for more information.

# %%
# !python tfci.py models
# Out:
# 2022-06-05 13:35:00.781987: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-06-05 13:35:00.787521: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:35:00.787551: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/pnagasam/.local/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:561: calling function (from tensorflow.python.eager.def_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# 2022-06-05 13:35:06.402650: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:35:06.402866: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:35:06.403024: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:35:06.403176: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:35:06.403328: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:35:06.403482: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:35:06.403649: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:35:06.403798: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:35:06.403830: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# The following models are available:
#
# * Models published in:
#   F. Mentzer, G. Toderici, M. Tschannen, E. Agustsson:
#   "High-Fidelity Generative Image Compression"
#   Adv. in Neural Information Processing Systems 33 (NeurIPS 2020)
#
#   hific-lo
#   hific-mi
#   hific-hi
#
#   These are the GAN-based models that were used for the paper and the demo
#   website (https://hific.github.io/). The target bitrates of these models are
#   0.14 bpp for "lo", 0.3 bpp for "mi", and 0.45 bpp for "hi".
#
# * Models published in:
#   D. Minnen, S. Singh:
#   "Channel-wise Autoregressive Entropy Models for Learned Image Compression"
#   Int. Conf. on Image Processing (ICIP 2020)
#
#   ms2020-cc10-mse-[1-10]
#   ms2020-cc8-msssim-[1-9]
#
#   These are channel-wise autoregressive models optimized for either MSE or
#   MS-SSIM. The MSE models have 10 splits along the channel dimension so a
#   latent tensor with 320 channels is split into 10 blocks with 32 channels
#   each. The MS-SSIM models have eight splits with 40 channels each.
#
#   All of the models include latent residual prediction (LRP) and were optimized
#   for 5,000,000 steps (MSE) or 4,000,000 steps (MS-SSIM) using Adam. The number
#   at the end of the name (1-10 or 1-9) indicates the quality level where larger
#   numbers imply higher quality and higher bit rates.
#
#   Although not used in the paper, we've been referring to this model as
#   "CHARM" for "CHannel-wise AutoRegressive Model".
#
#   Note: this model does not use the integer modification described below, so it
#   may be necessary to disable the GPU in order to reliably encode and decode.
#   This can be done by setting the environment variable `CUDA_VISIBLE_DEVICES`
#   to the empty string, e.g., using the command line:
#   CUDA_VISIBLE_DEVICES='' python tfci.py ...
#
# * Models published in:
#   D. Minnen, J. Ballé, G.D. Toderici:
#   "Joint Autoregressive and Hierarchical Priors for Learned Image Compression"
#   Adv. in Neural Information Processing Systems 31 (NeurIPS 2018)
#
#   mbt2018-mean-mse-[1-8]
#   mbt2018-mean-msssim-[1-8]
#
#   These are hyperprior models with non zero-mean Gaussian conditionals (without
#   autoregression), optimized for MSE (mean squared error) and MS-SSIM
#   (multiscale SSIM), respectively. The number 1-8 at the end indicates the
#   quality level (1: lowest, 8: highest).
#
#   While generalizing the hyperprior models to non-zero mean distributions
#   translates into some compression gains, the gains are not as high as for a
#   combined autoregressive and hierarchical prior. However, the runtime for
#   autoregressive priors is generally quite high.
#
# * Models published in:
#   J. Ballé, D. Minnen, S. Singh, S.J. Hwang, N. Johnston:
#   "Variational Image Compression with a Scale Hyperprior"
#   Int. Conf. on Learning Representations (ICLR), 2018
#
#   bmshj2018-factorized-mse-[1-8]
#   bmshj2018-factorized-msssim-[1-8]
#   bmshj2018-hyperprior-mse-[1-8]
#   bmshj2018-hyperprior-msssim-[1-8]
#
#   These are the factorized prior and hyperprior models optimized for MSE (mean
#   squared error) and MS-SSIM (multiscale SSIM), respectively. The number 1-8 at
#   the end indicates the quality level (1: lowest, 8: highest).
#
#   These models demonstrate the bit rate savings achieved by a hierarchical vs.
#   a factorized prior (entropy model).
#
# * Models published in:
#   J. Ballé:
#   "Efficient Nonlinear Transforms for Lossy Image Compression"
#   Picture Coding Symposium (PCS), 2018
#
#   b2018-leaky_relu-128-[1-4]
#   b2018-leaky_relu-192-[1-4]
#   b2018-gdn-128-[1-4]
#   b2018-gdn-192-[1-4]
#
#   These are nonlinear transform coders with factorized priors (entropy models)
#   optimized for MSE (mean squared error), with either leaky ReLU and GDN
#   activation functions, and 128 or 192 filters per layer. The number 1-4 at
#   the end indicates the quality level (1: lowest, 4: highest).
#
#   These models demonstrate the higher representational efficiency of GDN vs.
#   scalar activation functions such as leaky ReLU.
#
# Note: all the models using hierarchical/hyperpriors published above include a
# modification from:
# J. Ballé, N. Johnston, D. Minnen:
# "Integer Networks for Data Compression with Latent-Variable Models"
# Int. Conf. on Learning Representations (ICLR), 2019
#
# The conditional priors are modified to use integer arithmetic, in order to
# ensure consistent results across different hardware platforms. Other than this,
# the models are reproductions of the original models used in the publication.
# Therefore, performance may differ slightly.

# %%
# !python tfci.py compress hific-hi "DIV2K_valid_HR/0801.png"
# Out:
# 2022-06-05 13:36:09.397482: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-06-05 13:36:09.402483: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:36:09.402512: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/pnagasam/.local/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:561: calling function (from tensorflow.python.eager.def_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# 2022-06-05 13:36:12.572710: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:36:12.572856: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:36:12.572936: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:36:12.573013: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:36:12.573095: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:36:12.573173: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:36:12.573249: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:36:12.573325: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:36:12.573346: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-06-05 13:36:12.574231: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# I0605 13:36:24.137924 140339520550720 saver.py:1634] Saver not created because there are no variables in the graph to restore

# %%
# !python tfci.py decompress 0801.png.tfci
# Out:
# 2022-06-05 13:37:49.634046: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-06-05 13:37:49.639231: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:37:49.639262: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From /home/pnagasam/.local/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:561: calling function (from tensorflow.python.eager.def_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# 2022-06-05 13:37:54.794538: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:37:54.794723: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:37:54.794814: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:37:54.794917: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:37:54.795002: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:37:54.795105: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:37:54.795185: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:37:54.795280: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2022-06-05 13:37:54.795306: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# I0605 13:38:00.251470 140272491902784 saver.py:1634] Saver not created because there are no variables in the graph to restore
# 2022-06-05 13:38:04.140563: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
im_hific = cv2.imread('0801.png.tfci.png')

# %%
mean_squared_error(im, im_hific)
# Out:
# 29.90439585863844

# %%
ssim(im, im_hific, data_range=im.max() - im.min(), multichannel=True)
# Out:
# 0.9407058218524367

# %%
os.path.getsize("0801.png.tfci")
# Out:
# 189406
